# %% [markdown]
# 两层$5 \times 5$ 32, 64

# %%
from cifar10_mxnet import *;
cnn = network();
cnn.train(gpu = 0, niter = 2000000, test_interval = 500, lr = 0.001)
cnn.plot_result();
# Out:
# Epoch:  0 , Iteration  0
# 	Train Accuracy:	0.1
# 	Test Accuracy:		0.1111
# Epoch:  1 , Iteration  500
# 	Train Accuracy:	0.39
# 	Test Accuracy:		0.3983
# Epoch:  2 , Iteration  1000
# 	Train Accuracy:	0.42
# 	Test Accuracy:		0.4187
# Epoch:  3 , Iteration  1500
# 	Train Accuracy:	0.5
# 	Test Accuracy:		0.454
# Epoch:  4 , Iteration  2000
# 	Train Accuracy:	0.49
# 	Test Accuracy:		0.48
# Epoch:  5 , Iteration  2500
# 	Train Accuracy:	0.45
# 	Test Accuracy:		0.4391
# Epoch:  6 , Iteration  3000
# 	Train Accuracy:	0.49
# 	Test Accuracy:		0.5202
# Epoch:  7 , Iteration  3500
# 	Train Accuracy:	0.54
# 	Test Accuracy:		0.5303
# Epoch:  8 , Iteration  4000
# 	Train Accuracy:	0.53
# 	Test Accuracy:		0.5496
# Epoch:  9 , Iteration  4500
# 	Train Accuracy:	0.63
# 	Test Accuracy:		0.5437
# Epoch:  10 , Iteration  5000
# 	Train Accuracy:	0.57
# 	Test Accuracy:		0.5296
# Epoch:  11 , Iteration  5500
# 	Train Accuracy:	0.61
# 	Test Accuracy:		0.534
# Epoch:  12 , Iteration  6000
# ...
