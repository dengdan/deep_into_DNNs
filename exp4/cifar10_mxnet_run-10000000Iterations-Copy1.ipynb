# %% [markdown]
# 第二层一个$3 \times 3$ kernel,

# %%
from cifar10_mxnet import *;
cnn = network();
cnn.train(gpu = 0, niter = 10000000, test_interval = 500, lr = 0.0005)
cnn.plot_result();
# Out:
# Epoch:  0 , Iteration  0
# 	Train Accuracy:	0.1
# 	Test Accuracy:		0.1
# Epoch:  1 , Iteration  500
# 	Train Accuracy:	0.08
# 	Test Accuracy:		0.1001
# Epoch:  2 , Iteration  1000
# 	Train Accuracy:	0.09
# 	Test Accuracy:		0.1
# Epoch:  3 , Iteration  1500
# 	Train Accuracy:	0.15
# 	Test Accuracy:		0.1
# Epoch:  4 , Iteration  2000
# 	Train Accuracy:	0.18
# 	Test Accuracy:		0.1
# Epoch:  5 , Iteration  2500
# 	Train Accuracy:	0.13
# 	Test Accuracy:		0.1
# Epoch:  6 , Iteration  3000
# 	Train Accuracy:	0.07
# 	Test Accuracy:		0.1
# Epoch:  7 , Iteration  3500
# 	Train Accuracy:	0.11
# 	Test Accuracy:		0.1
# Epoch:  8 , Iteration  4000
# 	Train Accuracy:	0.11
# 	Test Accuracy:		0.1
# Epoch:  9 , Iteration  4500
# 	Train Accuracy:	0.12
# 	Test Accuracy:		0.1
# Epoch:  10 , Iteration  5000
# 	Train Accuracy:	0.05
# 	Test Accuracy:		0.1
# Epoch:  11 , Iteration  5500
# 	Train Accuracy:	0.05
# 	Test Accuracy:		0.1
# Epoch:  12 , Iteration  6000
# 	Train Accuracy:	0.08
# ...
