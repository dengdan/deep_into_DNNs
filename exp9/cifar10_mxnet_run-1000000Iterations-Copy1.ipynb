# %% [markdown]
# 两层$3 \times 3$ 32, 64

# %%
from cifar10_mxnet import *;
cnn = network();
cnn.train(gpu = 2, niter = 2000000, test_interval = 500, lr = 0.001)
cnn.plot_result();
# Out:
# Epoch:  0 , Iteration  0
# 	Train Accuracy:	0.08
# 	Test Accuracy:		0.0703
# Epoch:  1 , Iteration  500
# 	Train Accuracy:	0.35
# 	Test Accuracy:		0.405
# Epoch:  2 , Iteration  1000
# 	Train Accuracy:	0.43
# 	Test Accuracy:		0.4398
# Epoch:  3 , Iteration  1500
# 	Train Accuracy:	0.52
# 	Test Accuracy:		0.4976
# Epoch:  4 , Iteration  2000
# 	Train Accuracy:	0.52
# 	Test Accuracy:		0.4955
# Epoch:  5 , Iteration  2500
# 	Train Accuracy:	0.57
# 	Test Accuracy:		0.491
# Epoch:  6 , Iteration  3000
# 	Train Accuracy:	0.55
# 	Test Accuracy:		0.524
# Epoch:  7 , Iteration  3500
# 	Train Accuracy:	0.49
# 	Test Accuracy:		0.5288
# Epoch:  8 , Iteration  4000
# 	Train Accuracy:	0.52
# 	Test Accuracy:		0.5487
# Epoch:  9 , Iteration  4500
# 	Train Accuracy:	0.57
# 	Test Accuracy:		0.5375
# Epoch:  10 , Iteration  5000
# 	Train Accuracy:	0.59
# 	Test Accuracy:		0.5439
# Epoch:  11 , Iteration  5500
# 	Train Accuracy:	0.63
# 	Test Accuracy:		0.5471
# Epoch:  12 , Iteration  6000
# ...
