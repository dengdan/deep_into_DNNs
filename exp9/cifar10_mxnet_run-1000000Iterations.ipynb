# %% [markdown]
# 两层$3 \times 3$ 32, 64

# %%
from cifar10_mxnet import *;
cnn = network();
cnn.train(gpu = 2, niter = 1000000, test_interval = 500, lr = 0.001)
cnn.plot_result();
# Out:
# Epoch:  0 , Iteration  0
# 	Train Accuracy:	0.1
# 	Test Accuracy:		0.1158
# Epoch:  1 , Iteration  500
# 	Train Accuracy:	0.41
# 	Test Accuracy:		0.4169
# Epoch:  2 , Iteration  1000
# 	Train Accuracy:	0.49
# 	Test Accuracy:		0.453
# Epoch:  3 , Iteration  1500
# 	Train Accuracy:	0.44
# 	Test Accuracy:		0.446
# Epoch:  4 , Iteration  2000
# 	Train Accuracy:	0.42
# 	Test Accuracy:		0.4517
# Epoch:  5 , Iteration  2500
# 	Train Accuracy:	0.55
# 	Test Accuracy:		0.4768
# Epoch:  6 , Iteration  3000
# 	Train Accuracy:	0.54
# 	Test Accuracy:		0.5145
# Epoch:  7 , Iteration  3500
# 	Train Accuracy:	0.48
# 	Test Accuracy:		0.5271
# Epoch:  8 , Iteration  4000
# 	Train Accuracy:	0.58
# 	Test Accuracy:		0.512
# Epoch:  9 , Iteration  4500
# 	Train Accuracy:	0.64
# 	Test Accuracy:		0.5411
# Epoch:  10 , Iteration  5000
# 	Train Accuracy:	0.57
# 	Test Accuracy:		0.5383
# Epoch:  11 , Iteration  5500
# 	Train Accuracy:	0.56
# 	Test Accuracy:		0.5626
# Epoch:  12 , Iteration  6000
# ...
