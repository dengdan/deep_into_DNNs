# %%
from cifar10_mxnet import *;
cnn = network();
cnn.train(gpu = 0, niter = 1000000, test_interval = 500, lr = 0.001)
cnn.plot_result();
# Out:
# Epoch:  0 , Iteration  0
# 	Train Accuracy:	0.13
# 	Test Accuracy:		0.1197
# Epoch:  1 , Iteration  500
# 	Train Accuracy:	0.095
# 	Test Accuracy:		0.1
# Epoch:  2 , Iteration  1000
# 	Train Accuracy:	0.11
# 	Test Accuracy:		0.105
# Epoch:  3 , Iteration  1500
# 	Train Accuracy:	0.1575
# 	Test Accuracy:		0.2486
# Epoch:  4 , Iteration  2000
# 	Train Accuracy:	0.168
# 	Test Accuracy:		0.2728
# Epoch:  5 , Iteration  2500
# 	Train Accuracy:	0.198333333333
# 	Test Accuracy:		0.2936
# Epoch:  6 , Iteration  3000
# 	Train Accuracy:	0.215714285714
# 	Test Accuracy:		0.3007
# Epoch:  7 , Iteration  3500
# 	Train Accuracy:	0.23375
# 	Test Accuracy:		0.355
# Epoch:  8 , Iteration  4000
# 	Train Accuracy:	0.238888888889
# 	Test Accuracy:		0.3567
# Epoch:  9 , Iteration  4500
# 	Train Accuracy:	0.246
# 	Test Accuracy:		0.3516
# Epoch:  10 , Iteration  5000
# 	Train Accuracy:	0.261818181818
# 	Test Accuracy:		0.3794
# Epoch:  11 , Iteration  5500
# 	Train Accuracy:	0.28
# ...
